# %%
global_trend = df.groupby("year")["religious_affiliation"].mean()

plt.figure()
global_trend.plot()
plt.title("Global Religious Affiliation Over Time")
plt.ylabel("Average Religious Affiliation (%)")
plt.xlabel("Year")
plt.show()
